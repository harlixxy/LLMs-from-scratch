# %% [markdown]
# <a href="https://colab.research.google.com/github/harlixxy/LLMs-from-scratch/blob/main/llmfromscrach.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install uv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 26.5 MB/s eta 0:00:00
# ...

# %%
# !uv pip install -r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/requirements.txt --system
# https://github.com/rasbt/LLMs-from-scratch/blob/main/requirements.txt
# Out:
# Using Python 3.11.12 environment at: /usr
# Resolved 147 packages in 877ms
# ⠙ Preparing packages... (0/30)
# ⠙ Preparing packages... (0/30)
# jupyterlab-server ------------------------------     0 B/58.30 KiB
# ⠙ Preparing packages... (0/30)
# overrides  ------------------------------     0 B/17.41 KiB
# jupyterlab-server ------------------------------     0 B/58.30 KiB
# ⠙ Preparing packages... (0/30)
# python-json-logger ------------------------------     0 B/14.81 KiB
# overrides  ------------------------------     0 B/17.41 KiB
# jupyterlab-server ------------------------------     0 B/58.30 KiB
# ⠙ Preparing packages... (0/30)
# python-json-logger ------------------------------     0 B/14.81 KiB
# overrides  ------------------------------     0 B/17.41 KiB
# jupyterlab-server ------------------------------     0 B/58.30 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# ⠙ Preparing packages... (0/30)
# ...

# %% [markdown]
# # New Section
